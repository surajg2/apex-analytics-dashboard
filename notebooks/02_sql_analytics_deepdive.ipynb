# %% [markdown]
# # 💻 Notebook 02: Advanced SQL Analytics & Window Functions Deep Dive
#
# **Author:** Data Analyst Portfolio Showcase
# **Target Roles:** Senior Data Analyst / Analytics Engineer
#
# ---
# ## 🎯 Objective
# Executes advanced SQL queries utilizing Common Table Expressions (CTEs), Window Functions (`NTILE`, `DENSE_RANK`, `LAG`), and RFM segmentation directly against SQLite.

# %%
import sys
import pandas as pd
sys.path.append("..")
from utils.sql_runner import SQLRunner

runner = SQLRunner(db_path="../data/ecommerce.db", sql_dir="../sql")
print("SQL Files Available:", runner.list_sql_files())

# %% [markdown]
# ## 1. Executive Business KPI Overview

# %%
df_kpi = runner.run_sql_file("01_kpi_overview.sql")
df_kpi

# %% [markdown]
# ## 2. SQL Window Functions for Customer Lifetime Value & RFM Segmentation

# %%
df_cust = runner.run_sql_file("02_customer_analytics.sql")
df_cust.head(10)

# %% [markdown]
# ## 3. Month-over-Month (MoM) Growth Rate Analysis using `LAG()`

# %%
df_mom = runner.run_sql_file("04_sales_trends.sql")
df_mom.tail(12)
